# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import *
import time
import json
import pprint
driver = webdriver.Edge()
driver.get("https://www.icm.gov.mo/cn/events/list/")

moreButton = driver.find_element(By.CLASS_NAME, "moreButtonCSS")
time.sleep(4)
moreButton.click()
tables = driver.find_elements(By.CLASS_NAME, "col-md-12")

# %%
tr = tables[1].find_elements(By.XPATH, "//tr")

res=[]

for index,value in enumerate(tr):
    if index==0:continue
    res.append({
        "日期":value.find_elements(By.XPATH, "//td[1]")[index].text,
        "标题":value.find_elements(By.XPATH, "//td[2]")[index].text,
        "地点":value.find_elements(By.XPATH, "//td[3]")[index].text,
        "href":value.find_elements(By.XPATH, "//a")[index].get_attribute("href"),
    })

# %%
res
# Out:
# [{'日期': '2021年1月20日至2023年12月31日',
#   '标题': '360°全景虛擬展廳',
#   '地点': ' ',
#   'href': 'https://www.icm.gov.mo/cn/'},
#  {'日期': '2021年11月12日至2022年2月27日',
#   '标题': '太璞如琢——崔如琢藝術澳門大展',
#   '地点': '澳門藝術博物館',
#   'href': 'https://www.icm.gov.mo/gb/'},
#  {'日期': '2021年11月15日至2022年5月15日',
#   '标题': '澳門幫扶貴州省從江縣脫貧攻堅展',
#   '地点': '待定',
#   'href': 'https://www.icm.gov.mo/pt/'},
#  {'日期': '2021年11月20日至2022年2月6日',
#   '标题': '多棱•互觀－－國際當代藝術邀請展',
#   '地点': '澳門藝術博物館',
#   'href': 'https://www.icm.gov.mo/en/'},
#  {'日期': '2021年11月30日 星期二 11:00, 12:00\n2022年4月12日 星期二 11:00, 12:00',
#   '标题': '《樂漫博物館》',
#   '地点': '澳門博物館',
#   'href': 'https://www.icm.gov.mo/cn/'},
#  {'日期': '2021年12月1日至2022年1月16日',
#   '标题': '聖誕限時優惠',
#   '地点': ' ',
#   'href': 'https://www.icm.gov.mo/cn/events/list/#'},
#  {'日期': '2021年12月4日至2022年4月30日',
#   '标题': '內港文化深度遊．戲',
#   '地点': '多個地點',
#   'href': 'https://www.icm.gov.mo/cn/introduction'},
#  {'日期': '2021年12月11日至2022年3月6日',
#   '标题': '“御瓷菁華——故宮博物院藏明代御窯瓷器”展',
#   '地点': '澳門藝術博物館',
#   'href': 'https://www.icm.gov.mo/cn/law'},
#  {'日期': '2021年12月17日至2022年2月18日',
#   '标题': '永福圍——澳門高校巷、里、圍軟文及短視頻特展',
#   '地点': '永福圍10號',
#   'href': 'https://www.icm.gov.mo/cn/ICMAnnualReports'},
#  {'日期': '2022年1月8日 星期六 14:30, 15:30\n2022年7月2日 星期六 14:30, 15:30',
#   '标题': '《樂漫博物館》',
#   '地点': '澳門茶文化館',
#   'href': 'https://www.icm.gov.mo/cn/structure'},
#  {'日期': '2022年1月12日至14日 16:00-18:00\n2022年1月15日至16日 10:00-12:00, 13:00-15:00, 16:00-18:00\n2022年1月17日 星期一 16:00-18:00\n2022年1月18日至21日 16:00-18:00\n2022年1月22日至23日 10:00-12:00, 13:00-15:00, 16:00-18:00',
#   '标题': '舞蹤生有 AΦE（英國）',
#   '地点': '氹仔中央公園 蘭花前地休憩區',
#   'href': 'https://www.icm.gov.mo/cn/DPC'},
#  {'日期': '2022年1月12日至14日 19:00, 21:00\n2022年1月15日至16日 15:00, 17:00, 19:00, 21:00',
#   '标题': '聲音劇場《回家》 愛丁堡前沿劇展原創作品',
#   '地点': '葉挺將軍故居',
#   'href': 'https://www.icm.gov.mo/cn/DPICC'},
#  {'日期': '2022年1月12日至15日 20:00, 20:30, 21:00, 21:30, 22:00\n2022年1月16日 星期日 20:00, 20:30, 21:00, 21:30',
#   '标题': '我想行開吓，想忘記咗呢個世界 破藝術工作室',
#   '地点': '旅遊塔',
#   'href': 'https://www.icm.gov.mo/cn/DGBP'},
#  {'日期': '2022年1月12日至16日 18:00-22:00',
#   '标题': '尋季 吳少英',
#   '地点': '聖方濟各斜巷',
#   'href': 'https://www.icm.gov.mo/cn/DOGAF'},
#  {'日期': '2022年1月12日至23日',
#   '标题': '竹粉巨匠 Aline da Silva Mendes',
#   '地点': '大堂前地休憩區',
#   'href': 'https://www.icm.gov.mo/cn/DDAE'},
#  {'日期': '2022年1月12日至23日',
#   '标题': '永不回來的風景',
#   '地点': ' ',
#   'href': 'https://www.icm.gov.mo/cn/DM'},
#  {'日期': '2022年1月12日至17日 12:00-20:00\n2022年1月18日至23日 12:00-20:00',
#   '标题': '人人藝術展',
#   '地点': '花城公園 蘭花前地休憩區',
#   'href': 'https://www.icm.gov.mo/cn/AM'},
#  {'日期': '2022年1月13日至15日 14:00-18:00',
#   '标题': '共生舞工作坊',
#   '地点': '沙梨頭活動中心',
#   'href': 'https://www.icm.gov.mo/cn/CM'},
#  {'日期': '2022年1月13日至16日 16:30',
#   '标题': '偷渡客 袁一豪',
#   '地点': '待定',
#   'href': 'https://www.icm.gov.mo/cn/DCC'},
#  {'日期': '2022年1月14日至16日',
#   '标题': '祐漢生活指南',
#   '地点': '澳門菜農子弟學校',
#   'href': 'https://www.icm.gov.mo/cn/DEPUB'},
#  {'日期': '2022年1月14日至16日 10:00-19:00',
#   '标题': '李倩綺花繪裝置藝術展',
#   '地点': '文化局文化遺產廳花園',
#   'href': 'https://www.icm.gov.mo/cn/CCE'},
#  {'日期': '2022年1月15日至16日 15:00-16:30',
#   '标题': '花繪工作坊',
#   '地点': '文化局文化遺產廳花園',
#   'href': 'https://www.icm.gov.mo/cn/events/list/#'},
#  {'日期': '2022年1月15日至16日 10:00, 11:00, 12:00, 14:00, 15:00, 16:00, 17:00, 19:00, 20:00, 21:00, 22:00\n2022年1月17日至18日 18:00, 19:00, 20:00, 21:00, 22:00',
#   '标题': '空．一人一世界 蕭嘉儀',
#   '地点': '舊法院大樓',
#   'href': 'https://www.mam.gov.mo/'},
#  {'日期': '2022年1月15日至16日 15:00, 17:00',
#   '标题': '新與舊之間 滾動傀儡另類劇場',
#   '地点': '戲偶館',
#   'href': 'https://www.macaumuseum.gov.mo/'},
#  {'日期': '2022年1月15日至16日 12:00, 14:00, 17:00',
#   '标题': '心流花隅 零距離合作社',
#   '地点': '文化局文化遺產廳花園',
#   'href': 'https://www.library.gov.mo/'},
#  {'日期': '2022年1月15日至16日 15:00',
#   '标题': '舞動紋理 梳打埠實驗工場藝術協會 x 崗頂明愛老人中心',
#   '地点': '鄭家大屋',
#   'href': 'https://www.archives.gov.mo/'},
#  {'日期': '2022年1月15日 星期六 19:00-20:00',
#   '标题': '預置鋼琴解構工作坊',
#   '地点': '20hz貳拾赫茲藝術空間',
#   'href': 'https://www.ccm.gov.mo/'},
#  {'日期': '2022年1月15日 星期六 19:00-20:00; 20:00-21:00',
#   '标题': '街舞補習天王',
#   '地点': 'T劇場',
#   'href': 'https://www.conservatory.gov.mo/'},
#  {'日期': '2022年1月15日至16日 11:30, 14:30\n2022年1月22日至23日 11:30, 14:30',
#   '标题': '後疫情時代的“瘋” 吳凱婷 x 蘇文杰 x 吳麗嫦',
#   '地点': '文化創意產業教學及研究中心多用途室',
#   'href': 'https://www.wh.mo/mandarinhouse/'},
#  {'日期': '2022年1月16日至22日 18:00-18:30, 18:30-19:00, 19:00-19:30 *',
#   '标题': '租客 古英元',
#   '地点': '藝珍文化教育中心',
#   'href': 'https://www.wh.mo/LouKau/'},
#  {'日期': '2022年1月16日至22日 19:30-23:00',
#   '标题': '換物．漢誌',
#   '地点': '祐漢二街小販區',
#   'href': 'https://www.icm.gov.mo/cn/OldCourtBuilding'},
#  {'日期': '2022年1月16日 星期日 11:00',
#   '标题': '踢館賽 澳門舞者工作室',
#   '地点': '板樟堂前地',
#   'href': 'https://www.wh.mo/theatre/'},
#  {'日期': '2022年1月16日 星期日 20:00',
#   '标题': '《春意盎然》',
#   '地点': '澳門文化中心綜合劇院',
#   'href': 'https://www.icm.gov.mo/cn/YeTing'},
#  {'日期': '2022年1月17日 星期一 19:30\n2022年1月18日至19日 16:30, 19:30',
#   '标题': '未境作業．挫敗之慾（中學生專場） Company Weinheimer/Elber（瑞士） x 澳門弱智人士家長協進會 x 風盒子社區藝術發展協會',
#   '地点': '舊法院大樓黑盒劇場',
#   'href': 'https://www.icm.gov.mo/cn/MountFortressCorridor'},
#  {'日期': '2022年1月18日至2月11日 10:00-19:00',
#   '标题': '駕駛座的那個小孩 鄭家和',
#   '地点': '望廈山房',
#   'href': 'https://www.icm.gov.mo/cn/stJose'},
#  {'日期': '2022年1月20日至22日 19:30, 21:30',
#   '标题': '鐵打 程嘉敏',
#   '地点': '海事工房2號',
#   'href': 'https://www.icm.gov.mo/cn/NavyYardNo.1'},
#  {'日期': '2022年1月22日 星期六 15:00',
#   '标题': '全民魔法影院 蘇大新 x 孫振新 x 王啟仁',
#   '地点': '柏蕙活動中心',
#   'href': 'https://www.icm.gov.mo/cn/NavyYardNo.2'},
#  {'日期': '2022年1月22日 星期六 18:00, 21:00\n2022年1月23日 星期日 15:00',
#   '标题': '湮涅的情愫：八味之奏鳴與間奏 澳門現代音樂協會',
#   '地点': '舊法院大樓黑盒劇場',
#   'href': 'https://www.macaucci.gov.mo/cn/detail/46'},
#  {'日期': '2022年1月22日至23日 14:30, 15:00, 15:30, 16:00',
#   '标题': '過客 黃穎駿 x 黎梓盈',
#   '地点': '祐成工業大廈',
#   'href': 'https://www.icm.gov.mo/cn/XianXingHai'},
#  {'日期': '2022年1月22日至23日 15:00',
#   '标题': '身體演異 丸仔（香港） x 澳門明愛創明坊',
#   '地点': '東方基金會',
#   'href': 'https://www.icm.gov.mo/cn/GuiaFortress'},
#  {'日期': '2022年1月22日至23日 16:30-17:30\n2022年1月22日 星期六 17:30-19:00',
#   '标题': '“共融藝術點策劃”放映及分享會',
#   '地点': '東方基金會會址',
#   'href': 'https://www.ajti.gov.mo/'},
#  {'日期': '2022年1月23日 星期日 17:00-20:00',
#   '标题': 'Fringe Exchange：節慶連線',
#   '地点': '天21',
#   'href': 'https://www.icm.gov.mo/cn/NightWatchHouse'},
#  {'日期': '2022年1月23日 星期日 11:30-13:00',
#   '标题': '花生友之約',
#   '地点': '官樂怡基金會',
#   'href': 'https://www.cinematheque-passion.mo/'},
#  {'日期': '2022年1月23日 星期日 14:30-16:00',
#   '标题': '當代藝術與劇場的跨領域座談會',
#   '地点': '369合伙小鎮',
#   'href': 'https://www4.icm.gov.mo/cotaimuseum/'},
#  {'日期': '2022年1月29日 星期六 14:30, 15:30',
#   '标题': '《樂漫博物館》',
#   '地点': '饒宗頤學藝館',
#   'href': 'https://www.icm.gov.mo/cn/housesmuseum/'},
#  {'日期': '2022年2月11日 星期五 20:00',
#   '标题': '《情約一天》情人節音樂會',
#   '地点': '百老匯舞台',
#   'href': 'https://www.icm.gov.mo/handovermuseum/'},
#  {'日期': '2022年3月4日 星期五 20:00',
#   '标题': '《風‧魅》吹管樂專場音樂會',
#   '地点': '崗頂劇院',
#   'href': 'https://www.icm.gov.mo/cn/KunIamEcumenical'},
#  {'日期': '2022年3月11日 星期五 18:30',
#   '标题': '《愛社區樂同行》',
#   '地点': '澳門仁慈堂婆仔屋',
#   'href': 'https://www4.icm.gov.mo/pawnshop/PawnTrdChi.html'},
#  {'日期': '2022年3月19日 星期六 20:00',
#   '标题': '《影視好聲音3》',
#   '地点': '百老匯舞台',
#   'href': 'https://www.icm.gov.mo/cn/StPaul'},
#  {'日期': '2022年3月26日 星期六 14:30, 15:45',
#   '标题': '《樂滿世遺》',
#   '地点': '盧家大屋',
#   'href': 'https://www.icm.gov.mo/cn/NaTcha'},
#  {'日期': '',
#   '标题': '',
#   '地点': '',
#   'href': 'https://www.macaumuseum.gov.mo/visit/chong-sai-pharmacy'},
#  {'日期': '2022年4月1日 星期五 20:00',
#   '标题': '《琴聲漫漫》',
#   '地点': '崗頂劇院',
#   'href': 'https://www.macaumuseum.gov.mo/w3MMabout/MemorialMuseum.aspx'},
#  {'日期': '2022年4月9日 星期六 14:30, 15:30',
#   '标题': '《愛社區樂同行》',
#   '地点': '何東圖書館',
#   'href': 'https://www.icm.gov.mo/cn/TapSiac'},
#  {'日期': '2022年4月23日 星期六 15:00',
#   '标题': '《遊園聽曲》',
#   '地点': '大炮台花園',
#   'href': 'https://www.icm.gov.mo/cn/mesquita'},
#  {'日期': '2022年4月30日 星期六 11:00',
#   '标题': '《遊園聽曲》',
#   '地点': '白鴿巢公園',
#   'href': 'https://www.icm.gov.mo/cn/ox'},
#  {'日期': '2022年5月7日 星期六 14:30, 15:30\n2022年6月18日 星期六 14:30, 15:30\n2022年7月16日 星期六 14:30, 15:30',
#   '标题': '《愛社區樂同行》',
#   '地点': '氹仔圖書館',
#   'href': 'https://www.icm.gov.mo/cn/PIT'},
#  {'日期': '2022年5月13日 星期五 20:00',
#   '标题': '第三十二屆澳門藝術節《汪明荃與澳門中樂團》',
#   '地点': '倫敦人劇場',
#   'href': 'https://www.icm.gov.mo/cn/events/list/#'},
#  {'日期': '2022年5月29日 星期日 16:00',
#   '标题': '親子音樂劇場《中樂魔法棒》(吹管樂專場音樂會)',
#   '地点': '百老匯舞台',
#   'href': 'https://www.icm.gov.mo/cn/news'},
#  {'日期': '2022年6月12日 星期日 20:00',
#   '标题': '《巔峰之夜》',
#   '地点': '澳門文化中心綜合劇院',
#   'href': None},
#  {'日期': '2022年6月25日 星期六 20:00',
#   '标题': '《樂蘊彈撥》彈撥樂專場音樂會',
#   '地点': '崗頂劇院',
#   'href': 'https://www.icm.gov.mo/cn/announcement'},
#  {'日期': '2022年7月8日 星期五 20:00',
#   '标题': '《鬧翻天》敲擊樂專場音樂會',
#   '地点': '崗頂劇院',
#   'href': 'https://www.icm.gov.mo/cn/announcement2'},
#  {'日期': '2022年7月31日 星期日 20:00',
#   '标题': '2021-22樂季閉幕音樂會《聲聲入心》',
#   '地点': '澳門文化中心綜合劇院',
#   'href': None}]

# %%
with open("data.json", "w",encoding="utf8",) as f:
    json.dump(res, f, indent=4,ensure_ascii=False,sort_keys=True)
